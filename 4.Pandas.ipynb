# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    'Country':np.random.choice(['India', 'Usa', 'Uk', 'Aus'], 20, True),
    'Salary':np.random.randint(30, 90, 20),
    'Weight':np.random.randint(50, 95, 20),
    'Height':np.random.randint(120, 180, 20)
}, index=[chr(65+i) for i in range(20)])

# %%
df
# Out:
#   Country  Salary  Weight  Height
# A     Usa      51      71     174
# B     Usa      47      73     146
# C   India      57      67     134
# D     Aus      77      64     145
# E     Usa      67      65     160
# F      Uk      34      70     146
# G   India      36      62     143
# H     Usa      57      87     164
# I     Aus      78      85     164
# J      Uk      43      69     131
# K     Usa      51      81     173
# L     Aus      84      92     174
# M      Uk      58      69     144
# N     Aus      71      55     160
# O   India      33      60     125
# P      Uk      81      89     162
# Q     Aus      68      69     127
# R      Uk      45      78     149
# S   India      71      81     126
# T     Aus      81      56     121

# %%
df.loc[['D', 'F'], ['Salary', 'Height']]
# Out:
#    Salary  Height
# D      77     145
# F      34     146

# %%
df.loc[['D', 'F'], ['Salary', 'Height']] = np.nan

# %%
df
# Out:
#   Country  Salary  Weight  Height
# A     Usa    51.0      71   174.0
# B     Usa    47.0      73   146.0
# C   India    57.0      67   134.0
# D     Aus     NaN      64     NaN
# E     Usa    67.0      65   160.0
# F      Uk     NaN      70     NaN
# G   India    36.0      62   143.0
# H     Usa    57.0      87   164.0
# I     Aus    78.0      85   164.0
# J      Uk    43.0      69   131.0
# K     Usa    51.0      81   173.0
# L     Aus    84.0      92   174.0
# M      Uk    58.0      69   144.0
# N     Aus    71.0      55   160.0
# O   India    33.0      60   125.0
# P      Uk    81.0      89   162.0
# Q     Aus    68.0      69   127.0
# R      Uk    45.0      78   149.0
# S   India    71.0      81   126.0
# T     Aus    81.0      56   121.0

# %%
df.isna().sum()
# Out:
# Country    0
# Salary     2
# Weight     0
# Height     2
# dtype: int64

# %%
df.isna().sum(axis=1)
# Out:
# A    0
# B    0
# C    0
# D    2
# E    0
# F    2
# G    0
# H    0
# I    0
# J    0
# K    0
# L    0
# M    0
# N    0
# O    0
# P    0
# Q    0
# R    0
# S    0
# T    0
# dtype: int64

# %%
df
# Out:
#   Country  Salary  Weight  Height
# A     Usa    51.0      71   174.0
# B     Usa    47.0      73   146.0
# C   India    57.0      67   134.0
# D     Aus     NaN      64     NaN
# E     Usa    67.0      65   160.0
# F      Uk     NaN      70     NaN
# G   India    36.0      62   143.0
# H     Usa    57.0      87   164.0
# I     Aus    78.0      85   164.0
# J      Uk    43.0      69   131.0
# K     Usa    51.0      81   173.0
# L     Aus    84.0      92   174.0
# M      Uk    58.0      69   144.0
# N     Aus    71.0      55   160.0
# O   India    33.0      60   125.0
# P      Uk    81.0      89   162.0
# Q     Aus    68.0      69   127.0
# R      Uk    45.0      78   149.0
# S   India    71.0      81   126.0
# T     Aus    81.0      56   121.0

# %%
df['Salary'].isna().sum()
# Out:
# 2

# %%
df['Salary'].fillna(df['Salary'].mean())
# Out:
# A    51.000000
# B    47.000000
# C    57.000000
# D    59.944444
# E    67.000000
# F    59.944444
# G    36.000000
# H    57.000000
# I    78.000000
# J    43.000000
# K    51.000000
# L    84.000000
# M    58.000000
# N    71.000000
# O    33.000000
# P    81.000000
# Q    68.000000
# R    45.000000
# S    71.000000
# T    81.000000
# Name: Salary, dtype: float64

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())

# %%
df
# Out:
#   Country     Salary  Weight  Height
# A     Usa  51.000000      71   174.0
# B     Usa  47.000000      73   146.0
# C   India  57.000000      67   134.0
# D     Aus  59.944444      64     NaN
# E     Usa  67.000000      65   160.0
# F      Uk  59.944444      70     NaN
# G   India  36.000000      62   143.0
# H     Usa  57.000000      87   164.0
# I     Aus  78.000000      85   164.0
# J      Uk  43.000000      69   131.0
# K     Usa  51.000000      81   173.0
# L     Aus  84.000000      92   174.0
# M      Uk  58.000000      69   144.0
# N     Aus  71.000000      55   160.0
# O   India  33.000000      60   125.0
# P      Uk  81.000000      89   162.0
# Q     Aus  68.000000      69   127.0
# R      Uk  45.000000      78   149.0
# S   India  71.000000      81   126.0
# T     Aus  81.000000      56   121.0

# %%
df.loc[['H','J'], ['Height', 'Weight']] = [[90, 150], [50, 160]]

# %%
df
# Out:
#   Country     Salary  Weight  Height
# A     Usa  51.000000      71   174.0
# B     Usa  47.000000      73   146.0
# C   India  57.000000      67   134.0
# D     Aus  59.944444      64     NaN
# E     Usa  67.000000      65   160.0
# F      Uk  59.944444      70     NaN
# G   India  36.000000      62   143.0
# H     Usa  57.000000     150    90.0
# I     Aus  78.000000      85   164.0
# J      Uk  43.000000     160    50.0
# K     Usa  51.000000      81   173.0
# L     Aus  84.000000      92   174.0
# M      Uk  58.000000      69   144.0
# N     Aus  71.000000      55   160.0
# O   India  33.000000      60   125.0
# P      Uk  81.000000      89   162.0
# Q     Aus  68.000000      69   127.0
# R      Uk  45.000000      78   149.0
# S   India  71.000000      81   126.0
# T     Aus  81.000000      56   121.0

# %% [markdown]
#     weight < 70
#
#     weight > 90

# %%
df[(df['Weight'] < 70) | (df['Weight'] > 90)]
# Out:
#   Country     Salary  Weight  Height
# C   India  57.000000      67   134.0
# D     Aus  59.944444      64     NaN
# E     Usa  67.000000      65   160.0
# G   India  36.000000      62   143.0
# H     Usa  57.000000     150    90.0
# J      Uk  43.000000     160    50.0
# L     Aus  84.000000      92   174.0
# M      Uk  58.000000      69   144.0
# N     Aus  71.000000      55   160.0
# O   India  33.000000      60   125.0
# Q     Aus  68.000000      69   127.0
# T     Aus  81.000000      56   121.0

# %%
idx = df[(df['Weight'] < 70) | (df['Weight'] > 90)].index
idx
# Out:
# Index(['C', 'D', 'E', 'G', 'H', 'J', 'L', 'M', 'N', 'O', 'Q', 'T'], dtype='object')

# %%
df.loc[idx, ['Weight']] = np.median(df['Weight'])

# %%
df
# Out:
#   Country     Salary  Weight  Height
# A     Usa  51.000000    71.0   174.0
# B     Usa  47.000000    73.0   146.0
# C   India  57.000000    70.5   134.0
# D     Aus  59.944444    70.5     NaN
# E     Usa  67.000000    70.5   160.0
# F      Uk  59.944444    70.0     NaN
# G   India  36.000000    70.5   143.0
# H     Usa  57.000000    70.5    90.0
# I     Aus  78.000000    85.0   164.0
# J      Uk  43.000000    70.5    50.0
# K     Usa  51.000000    81.0   173.0
# L     Aus  84.000000    70.5   174.0
# M      Uk  58.000000    70.5   144.0
# N     Aus  71.000000    70.5   160.0
# O   India  33.000000    70.5   125.0
# P      Uk  81.000000    89.0   162.0
# Q     Aus  68.000000    70.5   127.0
# R      Uk  45.000000    78.0   149.0
# S   India  71.000000    81.0   126.0
# T     Aus  81.000000    70.5   121.0

# %%
netflix = pd.read_csv('netflix-rotten-tomatoes-metacritic-imdb.csv')
netflix
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15480 entries, 0 to 15479
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  15480 non-null  object
#  1   Genre                  13770 non-null  object
#  2   Tags                   15413 non-null  object
#  3   Languages              13545 non-null  object
#  4   Series or Movie        15480 non-null  object
#  5   Hidden Gem Score       13379 non-null  float64
#  6   Country Availability   15461 non-null  object
#  7   Runtime                15479 non-null  object
#  8   Director               10772 non-null  object
#  9   Writer                 11150 non-null  object
#  10  Actors                 13555 non-null  object
#  11  View Rating            8456 non-null   object
#  12  IMDb Score             13381 non-null  float64
#  13  Rotten Tomatoes Score  6382 non-null   float64
# ...

# %%
df.describe()
# Out:
#           Salary     Weight      Height
# count  20.000000  20.000000   18.000000
# mean   59.944444  73.700000  140.111111
# std    15.059434   5.763771   31.613268
# min    33.000000  70.000000   50.000000
# 25%    50.000000  70.500000  126.250000
# 50%    58.972222  70.500000  145.000000
# 75%    71.000000  74.250000  161.500000
# max    84.000000  89.000000  174.000000

# %%
netflix.isna().sum().sort_values(ascending=False)
# Out:
# Boxoffice                11473
# Metacritic Score         11144
# Production House         10331
# Awards Received           9405
# Rotten Tomatoes Score     9098
# TMDb Trailer              8286
# Trailer Site              8286
# Awards Nominated For      7819
# View Rating               7024
# Director                  4708
# Writer                    4330
# Poster                    3638
# IMDb Link                 2303
# Release Date              2107
# Hidden Gem Score          2101
# IMDb Votes                2101
# IMDb Score                2099
# Languages                 1935
# Actors                    1925
# Genre                     1710
# Tags                        67
# Country Availability        19
# Summary                      9
# Runtime                      1
# Netflix Link                 0
# Image                        0
# Netflix Release Date         0
# Series or Movie              0
# Title                        0
# dtype: int64

# %%
netflix.isna().sum().sort_values(ascending=False) / netflix.shape[0] * 100
# Out:
# Boxoffice                74.114987
# Metacritic Score         71.989664
# Production House         66.737726
# Awards Received          60.755814
# Rotten Tomatoes Score    58.772610
# TMDb Trailer             53.527132
# Trailer Site             53.527132
# Awards Nominated For     50.510336
# View Rating              45.374677
# Director                 30.413437
# Writer                   27.971576
# Poster                   23.501292
# IMDb Link                14.877261
# Release Date             13.611111
# Hidden Gem Score         13.572351
# IMDb Votes               13.572351
# IMDb Score               13.559432
# Languages                12.500000
# Actors                   12.435401
# Genre                    11.046512
# Tags                      0.432817
# Country Availability      0.122739
# Summary                   0.058140
# Runtime                   0.006460
# Netflix Link              0.000000
# Image                     0.000000
# Netflix Release Date      0.000000
# ...

# %%
netflix['Boxoffice']
# Out:
# 0        $2,122,065
# 1           $70,632
# 2           $16,263
# 3               NaN
# 4               NaN
#             ...
# 15475           NaN
# 15476           NaN
# 15477           NaN
# 15478           NaN
# 15479           NaN
# Name: Boxoffice, Length: 15480, dtype: object

# %%
netflix
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %%
netflix[(netflix['Languages'] == "Hindi") & (netflix['Series or Movie'] == 'Movie')]
# Out:
#                       Title                                   Genre  \
# 24          Indoo Ki Jawani                           Comedy, Drama
# 126          Eeb Allay Ooo!                           Comedy, Drama
# 141    Awara Paagal Deewana  Action, Comedy, Crime, Drama, Thriller
# 395           Hello Brother        Action, Comedy, Fantasy, Romance
# 447               Gangaajal                    Action, Crime, Drama
# ...                     ...                                     ...
# 13863               Fashion                                   Drama
# 13885    Ek Main Aur Ekk Tu                  Comedy, Drama, Romance
# 13925                  Boss            Action, Comedy, Crime, Drama
# 13997            Special 26                  Crime, Drama, Thriller
# 14764                  I Am          Documentary, Biography, Family
#
#                                                     Tags Languages  \
# 24     Action & Adventure,Bollywood Films,Comedies,Ad...     Hindi
# ...

# %%
netflix[netflix['Series or Movie'] == 'Series']
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 3                                          ANNE+
# 6                                   Gleboka woda
# 7                                       Instynkt
# 23                   Girls und Panzer das Finale
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 3                                       Drama
# 6                                       Drama
# 7                                       Crime
# 23                  Animation, Action, Comedy
# ...                                       ...
# ...

# %%
netflix[netflix['Series or Movie'] == 'Movie']
# Out:
#                              Title                    Genre  \
# 1              HOW TO BUILD A GIRL                   Comedy
# 2                       Centigrade          Drama, Thriller
# 4                            Moxie  Animation, Short, Drama
# 5                 The Con-Heartist          Comedy, Romance
# 8                    Only a Mother                    Drama
# ...                            ...                      ...
# 15466                     LIFE 2.0              Documentary
# 15467                Brand New Day       Documentary, Music
# 15469            Bita e os Animais                      NaN
# 15470       Jochem Myjer: Yeeehaa!                      NaN
# 15473  Daniel Arends: Blessuretijd                   Comedy
#
#                                                     Tags Languages  \
# 1           Dramas,Comedies,Films Based on Books,British   English
# 2                                              Thrillers   English
# ...

# %%
11697 + 3783
# Out:
# 15480

# %%
data = netflix['Series or Movie'].value_counts()
data
# Out:
# Movie     11697
# Series     3783
# Name: Series or Movie, dtype: int64

# %%
data.plot(kind='bar')
# Out:
# <Axes: >

# %%
netflix['Languages'].value_counts()
# Out:
# English                        5133
# Japanese                       1213
# Korean                          541
# Spanish                         382
# Hindi                           329
#                                ...
# Hungarian, French, English        1
# Arabic, Nyanja, English           1
# Dutch, Flemish                    1
# Thai, Japanese                    1
# English, Hawaiian, Mandarin       1
# Name: Languages, Length: 1438, dtype: int64

# %%
s = netflix['Languages'].value_counts()
s.plot(kind='bar')
# Out:
# <Axes: >

# %%
sr = netflix['Languages'].value_counts()
sr[:20].plot(kind='bar')
# Out:
# <Axes: >

# %%
netflix.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
for i in netflix['Genre']:
    print(i)
# Out:
# Crime, Drama, Fantasy, Horror, Romance
# Comedy
# Drama, Thriller
# Drama
# Animation, Short, Drama
# Comedy, Romance
# Drama
# Crime
# Drama
# Comedy
# Comedy, Family, Fantasy
# Crime, Drama, Fantasy, Mystery, Thriller
# Drama
# Comedy, Drama
# Short, Drama
# Crime, Drama, Thriller
# Action, Adventure, Fantasy, Sci-Fi
# Adventure, Drama, Fantasy, Mystery
# Music
# Drama, Thriller
# Short
# Thriller
# Drama
# Animation, Action, Comedy
# Comedy, Drama
# Crime, Drama
# Drama, Sci-Fi
# Drama, Romance
# Comedy
# Action, Family, Sci-Fi, Thriller
# Biography, Drama, Thriller
# Drama
# Crime, Drama
# Drama
# Drama
# Action, Family, Sci-Fi, Thriller
# Drama
# Drama, Romance
# Animation, Drama, Sport
# nan
# Drama, Romance
# Biography, Drama
# Comedy
# Animation, Adventure, Family, Mystery
# Comedy
# Drama, Sci-Fi
# Drama
# Drama, War
# Drama, History, War
# Comedy, Crime, Drama
# Adventure, Drama, Sci-Fi, Thriller
# Documentary, Biography, Drama
# Comedy, Horror, Sci-Fi
# Drama
# ...

# %%
def fun(v):
    if type(v) == float:
        return False
    else:
        data = v.lower().split(', ')
        if 'comedy' in data:
            return True
        else:
            return False

# %%
for i in netflix['Genre']:
    print(fun(i))
# Out:
# False
# True
# False
# False
# False
# True
# False
# False
# False
# True
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# False
# False
# False
# True
# False
# False
# True
# False
# True
# True
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# True
# False
# False
# True
# False
# False
# False
# True
# False
# False
# False
# False
# False
# True
# False
# False
# True
# True
# False
# False
# False
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# True
# True
# False
# False
# True
# True
# False
# False
# False
# True
# False
# False
# False
# False
# True
# False
# False
# ...

# %%
netflix['Genre'].apply(fun)
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 15475    False
# 15476    False
# 15477     True
# 15478     True
# 15479     True
# Name: Genre, Length: 15480, dtype: bool

# %%
netflix[netflix['Genre'].apply(fun)]
# Out:
#                                            Title  \
# 1                            HOW TO BUILD A GIRL
# 5                               The Con-Heartist
# 9                                     Snowroller
# 10                                  Sunes Summer
# 13                         The Stig-Helmer Story
# ...                                          ...
# 15465                             13 Going on 30
# 15473                Daniel Arends: Blessuretijd
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                    Genre  \
# 1                                 Comedy
# 5                        Comedy, Romance
# 9                                 Comedy
# 10               Comedy, Family, Fantasy
# 13                         Comedy, Drama
# ...                                  ...
# 15465           Comedy, Fantasy, Romance
# ...
