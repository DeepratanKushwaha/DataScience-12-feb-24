# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("c:/Users/user/Desktop/Python_Mock_Test(1-280).xlsx")
data
# Out:
#       ID          Start time     Completion time      Email  Name  \
# 0      1 2021-07-02 21:51:56 2021-07-02 21:52:13  anonymous   NaN
# 1      2 2021-07-03 14:13:47 2021-07-03 14:18:16  anonymous   NaN
# 2      3 2021-07-03 14:18:11 2021-07-03 14:23:05  anonymous   NaN
# 3      4 2021-07-03 14:19:02 2021-07-03 14:23:40  anonymous   NaN
# 4      5 2021-07-03 14:14:44 2021-07-03 14:26:08  anonymous   NaN
# ..   ...                 ...                 ...        ...   ...
# 275  276 2021-07-03 17:12:25 2021-07-03 17:14:54  anonymous   NaN
# 276  277 2021-07-03 16:20:43 2021-07-03 17:17:03  anonymous   NaN
# 277  278 2021-07-03 16:49:17 2021-07-03 17:19:23  anonymous   NaN
# 278  279 2021-07-03 17:15:25 2021-07-03 17:30:20  anonymous   NaN
# 279  280 2021-07-03 17:05:35 2021-07-03 17:35:47  anonymous   NaN
#
#      Total points  Quiz feedback Please fill your full name?  \
# 0               1            NaN                         NaN
# ...

# %%
data['Email'].value_counts()
# Out:
# anonymous    280
# Name: Email, dtype: int64

# %%
data['Name'].value_counts()
# Out:
# Series([], Name: Name, dtype: int64)

# %%
print(data.columns)
# Out:
# Index(['ID', 'Start time', 'Completion time', 'Email', 'Name', 'Total points',
#        'Quiz feedback', 'Please fill your full name?',
#        'Points - Please fill your full name?',
#        'Feedback - Please fill your full name?',
#        ...
#        'Feedback -  What should be replace in blank space to get output as 33?\n\nnames1 = ['Amir', 'Bear', 'Charlton', 'Daman']\nnames2 = names1\nnames3 = names1\n\nnames2[0] = 'Alice'\nnames3[1] = 'Bob'\n\nsum = 0\nfor ls i...',
#        'Which should we write to get the output as NEWYORK or to access NEWYORK?\n\ndata = {1: {\n        "id" : 390669115,\n        "name" : "ProgramState",\n        "dataTypeName" : "text",\n        "descript...',
#        'Points - Which should we write to get the output as NEWYORK or to access NEWYORK?\n\ndata = {1: {\n        "id" : 390669115,\n        "name" : "ProgramState",\n        "dataTypeName" : "text",\n        "descript...',
# ...

# %%
len(data.columns)
# Out:
# 112

# %%
data.drop(['ID', 'Email', 'Name', 'Quiz feedback', 'Points - Please fill your full name?', 'Feedback - Please fill your full name?'], axis=1, inplace=True)

# %%
data.head()
# Out:
#            Start time     Completion time  Total points  \
# 0 2021-07-02 21:51:56 2021-07-02 21:52:13             1
# 1 2021-07-03 14:13:47 2021-07-03 14:18:16             9
# 2 2021-07-03 14:18:11 2021-07-03 14:23:05            14
# 3 2021-07-03 14:19:02 2021-07-03 14:23:40            14
# 4 2021-07-03 14:14:44 2021-07-03 14:26:08             9
#
#   Please fill your full name?       Please fill your email?  \
# 0                         NaN                           NaN
# 1               Vishal thakur  vishalthakur850900@gmail.com
# 2            Nikita prajapati         Nikitap8912@gmail.com
# 3                        ansh              ansh00@gmail.com
# 4              Krishna garare    krishnagararekkg@gmail.com
#
#    Points - Please fill your email?  Feedback - Please fill your email?  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# ...

# %%
df1 = data.iloc[:, :5]
df1
# Out:
#              Start time     Completion time  Total points  \
# 0   2021-07-02 21:51:56 2021-07-02 21:52:13             1
# 1   2021-07-03 14:13:47 2021-07-03 14:18:16             9
# 2   2021-07-03 14:18:11 2021-07-03 14:23:05            14
# 3   2021-07-03 14:19:02 2021-07-03 14:23:40            14
# 4   2021-07-03 14:14:44 2021-07-03 14:26:08             9
# ..                  ...                 ...           ...
# 275 2021-07-03 17:12:25 2021-07-03 17:14:54            57
# 276 2021-07-03 16:20:43 2021-07-03 17:17:03            32
# 277 2021-07-03 16:49:17 2021-07-03 17:19:23            45
# 278 2021-07-03 17:15:25 2021-07-03 17:30:20            51
# 279 2021-07-03 17:05:35 2021-07-03 17:35:47            19
#
#     Please fill your full name?        Please fill your email?
# 0                           NaN                            NaN
# 1                 Vishal thakur   vishalthakur850900@gmail.com
# 2              Nikita prajapati          Nikitap8912@gmail.com
# ...

# %%
data.head()
# Out:
#            Start time     Completion time  Total points  \
# 0 2021-07-02 21:51:56 2021-07-02 21:52:13             1
# 1 2021-07-03 14:13:47 2021-07-03 14:18:16             9
# 2 2021-07-03 14:18:11 2021-07-03 14:23:05            14
# 3 2021-07-03 14:19:02 2021-07-03 14:23:40            14
# 4 2021-07-03 14:14:44 2021-07-03 14:26:08             9
#
#   Please fill your full name?       Please fill your email?  \
# 0                         NaN                           NaN
# 1               Vishal thakur  vishalthakur850900@gmail.com
# 2            Nikita prajapati         Nikitap8912@gmail.com
# 3                        ansh              ansh00@gmail.com
# 4              Krishna garare    krishnagararekkg@gmail.com
#
#    Points - Please fill your email?  Feedback - Please fill your email?  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# ...

# %%
data.columns[5]
# Out:
# 'Points - Please fill your email?'

# %%
data.iloc[:, 7:]
# Out:
#     Please choose your batch?  Points - Please choose your batch?  \
# 0                         NaN                                 NaN
# 1                     Batch 2                                 NaN
# 2                     Batch 2                                 NaN
# 3                     Batch 2                                 NaN
# 4                     Batch 3                                 NaN
# ..                        ...                                 ...
# 275                   Batch 1                                 NaN
# 276                   Batch 3                                 NaN
# 277                   Batch 3                                 NaN
# 278                   Batch 1                                 NaN
# 279                   Batch 1                                 NaN
#
#      Feedback - Please choose your batch?       Please fill your branch?  \
# 0                                     NaN                            NaN
# ...

# %%
df2 = data.iloc[:, 7:13:3]
df2
# Out:
#     Please choose your batch?       Please fill your branch?
# 0                         NaN                            NaN
# 1                     Batch 2         Mechanical engineering
# 2                     Batch 2                             Cs
# 3                     Batch 2                             cs
# 4                     Batch 3                            CSE
# ..                        ...                            ...
# 275                   Batch 1                            CSE
# 276                   Batch 3                            CSE
# 277                   Batch 3                             CS
# 278                   Batch 1                          Ai&DS
# 279                   Batch 1  Electronics and communication
#
# [280 rows x 2 columns]

# %%
data.iloc[:, 13:]
# Out:
#     Which data type among the following is immutable  \
# 0                                                NaN
# 1                                               List
# 2                                         Dictionary
# 3                                                Set
# 4                                               List
# ..                                               ...
# 275                                           String
# 276                                           String
# 277                                           String
# 278                                           String
# 279                                           String
#
#      Points - Which data type among the following is immutable  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# ...

# %%
df3 = data.iloc[:, 14::3]
df3
# Out:
#      Points - Which data type among the following is immutable  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 275                                                  1
# 276                                                  1
# 277                                                  1
# 278                                                  1
# 279                                                  1
#
#      Points - Python is which type of language  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            0
# ...

# %%
df1
# Out:
#              Start time     Completion time  Total points  \
# 0   2021-07-02 21:51:56 2021-07-02 21:52:13             1
# 1   2021-07-03 14:13:47 2021-07-03 14:18:16             9
# 2   2021-07-03 14:18:11 2021-07-03 14:23:05            14
# 3   2021-07-03 14:19:02 2021-07-03 14:23:40            14
# 4   2021-07-03 14:14:44 2021-07-03 14:26:08             9
# ..                  ...                 ...           ...
# 275 2021-07-03 17:12:25 2021-07-03 17:14:54            57
# 276 2021-07-03 16:20:43 2021-07-03 17:17:03            32
# 277 2021-07-03 16:49:17 2021-07-03 17:19:23            45
# 278 2021-07-03 17:15:25 2021-07-03 17:30:20            51
# 279 2021-07-03 17:05:35 2021-07-03 17:35:47            19
#
#     Please fill your full name?        Please fill your email?
# 0                           NaN                            NaN
# 1                 Vishal thakur   vishalthakur850900@gmail.com
# 2              Nikita prajapati          Nikitap8912@gmail.com
# ...

# %%
df2
# Out:
#     Please choose your batch?       Please fill your branch?
# 0                         NaN                            NaN
# 1                     Batch 2         Mechanical engineering
# 2                     Batch 2                             Cs
# 3                     Batch 2                             cs
# 4                     Batch 3                            CSE
# ..                        ...                            ...
# 275                   Batch 1                            CSE
# 276                   Batch 3                            CSE
# 277                   Batch 3                             CS
# 278                   Batch 1                          Ai&DS
# 279                   Batch 1  Electronics and communication
#
# [280 rows x 2 columns]

# %%
df3
# Out:
#      Points - Which data type among the following is immutable  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 275                                                  1
# 276                                                  1
# 277                                                  1
# 278                                                  1
# 279                                                  1
#
#      Points - Python is which type of language  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            0
# ...

# %%
df3.sum(axis=1)
# Out:
# 0       1.0
# 1       9.0
# 2      14.0
# 3      14.0
# 4       9.0
#        ...
# 275    57.0
# 276    32.0
# 277    45.0
# 278    51.0
# 279    19.0
# Length: 280, dtype: float64

# %%
df1['Total points'] = df3.sum(axis=1).astype('int')

# %%
df1
# Out:
#              Start time     Completion time  Total points  \
# 0   2021-07-02 21:51:56 2021-07-02 21:52:13             1
# 1   2021-07-03 14:13:47 2021-07-03 14:18:16             9
# 2   2021-07-03 14:18:11 2021-07-03 14:23:05            14
# 3   2021-07-03 14:19:02 2021-07-03 14:23:40            14
# 4   2021-07-03 14:14:44 2021-07-03 14:26:08             9
# ..                  ...                 ...           ...
# 275 2021-07-03 17:12:25 2021-07-03 17:14:54            57
# 276 2021-07-03 16:20:43 2021-07-03 17:17:03            32
# 277 2021-07-03 16:49:17 2021-07-03 17:19:23            45
# 278 2021-07-03 17:15:25 2021-07-03 17:30:20            51
# 279 2021-07-03 17:05:35 2021-07-03 17:35:47            19
#
#     Please fill your full name?        Please fill your email?
# 0                           NaN                            NaN
# 1                 Vishal thakur   vishalthakur850900@gmail.com
# 2              Nikita prajapati          Nikitap8912@gmail.com
# ...

# %%
df2
# Out:
#     Please choose your batch?       Please fill your branch?
# 0                         NaN                            NaN
# 1                     Batch 2         Mechanical engineering
# 2                     Batch 2                             Cs
# 3                     Batch 2                             cs
# 4                     Batch 3                            CSE
# ..                        ...                            ...
# 275                   Batch 1                            CSE
# 276                   Batch 3                            CSE
# 277                   Batch 3                             CS
# 278                   Batch 1                          Ai&DS
# 279                   Batch 1  Electronics and communication
#
# [280 rows x 2 columns]

# %%
df3
# Out:
#      Points - Which data type among the following is immutable  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 275                                                  1
# 276                                                  1
# 277                                                  1
# 278                                                  1
# 279                                                  1
#
#      Points - Python is which type of language  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            0
# ...

# %%
df4 = pd.concat([df1, df2, df3], axis=1)
df4
# Out:
#              Start time     Completion time  Total points  \
# 0   2021-07-02 21:51:56 2021-07-02 21:52:13             1
# 1   2021-07-03 14:13:47 2021-07-03 14:18:16             9
# 2   2021-07-03 14:18:11 2021-07-03 14:23:05            14
# 3   2021-07-03 14:19:02 2021-07-03 14:23:40            14
# 4   2021-07-03 14:14:44 2021-07-03 14:26:08             9
# ..                  ...                 ...           ...
# 275 2021-07-03 17:12:25 2021-07-03 17:14:54            57
# 276 2021-07-03 16:20:43 2021-07-03 17:17:03            32
# 277 2021-07-03 16:49:17 2021-07-03 17:19:23            45
# 278 2021-07-03 17:15:25 2021-07-03 17:30:20            51
# 279 2021-07-03 17:05:35 2021-07-03 17:35:47            19
#
#     Please fill your full name?        Please fill your email?  \
# 0                           NaN                            NaN
# 1                 Vishal thakur   vishalthakur850900@gmail.com
# 2              Nikita prajapati          Nikitap8912@gmail.com
# ...

# %%
df4.isna().sum()
# Out:
# Start time                                                                                                                                                                                                                           0
# Completion time                                                                                                                                                                                                                      0
# Total points                                                                                                                                                                                                                         0
# Please fill your full name?                                                                                                                                                                                                          1
# ...

# %%
df4.shape
# Out:
# (280, 38)

# %%
df4.dropna(axis=1, how='all')
# Out:
#              Start time     Completion time  Total points  \
# 0   2021-07-02 21:51:56 2021-07-02 21:52:13             1
# 1   2021-07-03 14:13:47 2021-07-03 14:18:16             9
# 2   2021-07-03 14:18:11 2021-07-03 14:23:05            14
# 3   2021-07-03 14:19:02 2021-07-03 14:23:40            14
# 4   2021-07-03 14:14:44 2021-07-03 14:26:08             9
# ..                  ...                 ...           ...
# 275 2021-07-03 17:12:25 2021-07-03 17:14:54            57
# 276 2021-07-03 16:20:43 2021-07-03 17:17:03            32
# 277 2021-07-03 16:49:17 2021-07-03 17:19:23            45
# 278 2021-07-03 17:15:25 2021-07-03 17:30:20            51
# 279 2021-07-03 17:05:35 2021-07-03 17:35:47            19
#
#     Please fill your full name?        Please fill your email?  \
# 0                           NaN                            NaN
# 1                 Vishal thakur   vishalthakur850900@gmail.com
# 2              Nikita prajapati          Nikitap8912@gmail.com
# ...

# %%
df4.isna().sum(axis=1)
# Out:
# 0      5
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 275    1
# 276    1
# 277    1
# 278    1
# 279    1
# Length: 280, dtype: int64

# %%
df4.drop(0, inplace=True)

# %%
df4.head()
# Out:
#            Start time     Completion time  Total points  \
# 1 2021-07-03 14:13:47 2021-07-03 14:18:16             9
# 2 2021-07-03 14:18:11 2021-07-03 14:23:05            14
# 3 2021-07-03 14:19:02 2021-07-03 14:23:40            14
# 4 2021-07-03 14:14:44 2021-07-03 14:26:08             9
# 5 2021-07-03 14:20:41 2021-07-03 14:26:11            15
#
#   Please fill your full name?       Please fill your email?  \
# 1               Vishal thakur  vishalthakur850900@gmail.com
# 2            Nikita prajapati         Nikitap8912@gmail.com
# 3                        ansh              ansh00@gmail.com
# 4              Krishna garare    krishnagararekkg@gmail.com
# 5             Navansh Trivedi   navansh.trivedi13@gmail.com
#
#   Please choose your batch? Please fill your branch?  \
# 1                   Batch 2   Mechanical engineering
# 2                   Batch 2                       Cs
# 3                   Batch 2                       cs
# ...

# %%
df4.sort_values(by='Total points', ascending=False).head()
# Out:
#              Start time     Completion time  Total points  \
# 219 2021-07-03 14:15:06 2021-07-03 15:53:06            57
# 70  2021-07-03 14:53:24 2021-07-03 14:57:41            57
# 255 2021-07-03 14:23:21 2021-07-03 16:31:57            57
# 275 2021-07-03 17:12:25 2021-07-03 17:14:54            57
# 170 2021-07-03 14:13:28 2021-07-03 15:31:51            57
#
#     Please fill your full name?      Please fill your email?  \
# 219               Himanshu Soni  himanshunitesh123@gmail.com
# 70               Paplavi makode  pallavimakode1108@gmail.com
# 255                Ujjwal Singh      usb9300322722@gmail.com
# 275                Komal  patil     Patilkommu8383@gmail.com
# 170       Dhiraj kumar kushwaha  dhirajkushwaha002@gmail.com
#
#     Please choose your batch?       Please fill your branch?  \
# 219                   Batch 3                             EE
# 70                    Batch 2                            CSE
# ...

# %%
df4['Please choose your batch?'].value_counts()
# Out:
# Batch 1    112
# Batch 3     95
# Batch 2     72
# Name: Please choose your batch?, dtype: int64

# %%
df4[df4['Please choose your batch?'] == 'Batch 1'].sort_values(by='Total points', ascending=False).head()
# Out:
#              Start time     Completion time  Total points  \
# 275 2021-07-03 17:12:25 2021-07-03 17:14:54            57
# 170 2021-07-03 14:13:28 2021-07-03 15:31:51            57
# 38  2021-07-03 14:16:04 2021-07-03 14:45:05            55
# 68  2021-07-03 14:41:43 2021-07-03 14:56:50            55
# 248 2021-07-03 16:13:21 2021-07-03 16:18:38            55
#
#     Please fill your full name?      Please fill your email?  \
# 275                Komal  patil     Patilkommu8383@gmail.com
# 170       Dhiraj kumar kushwaha  dhirajkushwaha002@gmail.com
# 38                  Mayank Gaur          tomaluter@gmail.com
# 68                   yash balod           balodyash2002@.com
# 248            Pratham Mucchala  prathammuchhala16@gmail.com
#
#     Please choose your batch?                Please fill your branch?  \
# 275                   Batch 1                                     CSE
# 170                   Batch 1                                     CSE
# ...

# %%
df4[df4['Please choose your batch?'] == 'Batch 2'].sort_values(by='Total points', ascending=False).head()
# Out:
#              Start time     Completion time  Total points  \
# 255 2021-07-03 14:23:21 2021-07-03 16:31:57            57
# 70  2021-07-03 14:53:24 2021-07-03 14:57:41            57
# 182 2021-07-03 15:33:52 2021-07-03 15:38:33            55
# 260 2021-07-03 16:36:10 2021-07-03 16:41:59            55
# 185 2021-07-03 15:24:59 2021-07-03 15:38:49            55
#
#     Please fill your full name?       Please fill your email?  \
# 255                Ujjwal Singh       usb9300322722@gmail.com
# 70               Paplavi makode   pallavimakode1108@gmail.com
# 182             Samiksha Kabra      samikshakabra23@gmail.com
# 260              Sanjana Sharma     ssanjana1327.ss@gmail.com
# 185            Prayag Choudhary  prayagchoudhary126@gmail.com
#
#     Please choose your batch?       Please fill your branch?  \
# 255                   Batch 2  Electronics and Communication
# 70                    Batch 2                            CSE
# ...

# %%
df4[df4['Please choose your batch?'] == 'Batch 3'].sort_values(by='Total points', ascending=False).head()
# Out:
#              Start time     Completion time  Total points  \
# 236 2021-07-03 16:04:05 2021-07-03 16:10:13            57
# 219 2021-07-03 14:15:06 2021-07-03 15:53:06            57
# 217 2021-07-03 15:46:44 2021-07-03 15:51:32            56
# 146 2021-07-03 15:16:18 2021-07-03 15:24:52            55
# 120 2021-07-03 14:36:11 2021-07-03 15:15:45            52
#
#     Please fill your full name?       Please fill your email?  \
# 236              Shikha Khatri     shikhakhatri8855@gmail.com
# 219               Himanshu Soni   himanshunitesh123@gmail.com
# 217            Kratika lashkari  lashkarikratika410@gmail.com
# 146               Nihit malviya     Malviyanihit578@gmail.com
# 120             Shriraj Solanki    solankishriraj33@gmail.com
#
#     Please choose your batch? Please fill your branch?  \
# 236                   Batch 3                       Cs
# 219                   Batch 3                       EE
# 217                   Batch 3                      CSE
# ...

# %%
df4
# Out:
#              Start time     Completion time  Total points  \
# 1   2021-07-03 14:13:47 2021-07-03 14:18:16             9
# 2   2021-07-03 14:18:11 2021-07-03 14:23:05            14
# 3   2021-07-03 14:19:02 2021-07-03 14:23:40            14
# 4   2021-07-03 14:14:44 2021-07-03 14:26:08             9
# 5   2021-07-03 14:20:41 2021-07-03 14:26:11            15
# ..                  ...                 ...           ...
# 275 2021-07-03 17:12:25 2021-07-03 17:14:54            57
# 276 2021-07-03 16:20:43 2021-07-03 17:17:03            32
# 277 2021-07-03 16:49:17 2021-07-03 17:19:23            45
# 278 2021-07-03 17:15:25 2021-07-03 17:30:20            51
# 279 2021-07-03 17:05:35 2021-07-03 17:35:47            19
#
#     Please fill your full name?        Please fill your email?  \
# 1                 Vishal thakur   vishalthakur850900@gmail.com
# 2              Nikita prajapati          Nikitap8912@gmail.com
# 3                          ansh               ansh00@gmail.com
# ...

# %%
df4.columns
# Out:
# Index(['Start time', 'Completion time', 'Total points',
#        'Please fill your full name?', 'Please fill your email?',
#        'Please choose your batch?', 'Please fill your branch?',
#        'Points - Which data type among the following is immutable',
#        'Points - Python is which type of language',
#        'Points - What is Maximum possible length of identifier',
#        'Points - In which year was the Python language developed?',
#        'Points - Which is the correct extension of python file',
#        'Points - What do we use to define a block of code in Python language?',
#        'Points - Which of the following declaration is incorrect',
#        'Points - Which of the following is incorrect',
#        'Points - What will be the output of this code?\na = 10\nb = 20\nc = 2\nwhile a<b:\n    c += 2\n    a += 2\nprint(c)',
#        'Points - What will be the output of the code?\ni = 1\nwhile True:\n    if i%3 == 0:\n        break\n    print(i)\n \n    i + = 1',
# ...

# %% [markdown]
#     df.drop_duplicates()

# %%
df4.drop_duplicates('Please fill your full name?', keep='first')
# Out:
#              Start time     Completion time  Total points  \
# 1   2021-07-03 14:13:47 2021-07-03 14:18:16             9
# 2   2021-07-03 14:18:11 2021-07-03 14:23:05            14
# 3   2021-07-03 14:19:02 2021-07-03 14:23:40            14
# 4   2021-07-03 14:14:44 2021-07-03 14:26:08             9
# 5   2021-07-03 14:20:41 2021-07-03 14:26:11            15
# ..                  ...                 ...           ...
# 275 2021-07-03 17:12:25 2021-07-03 17:14:54            57
# 276 2021-07-03 16:20:43 2021-07-03 17:17:03            32
# 277 2021-07-03 16:49:17 2021-07-03 17:19:23            45
# 278 2021-07-03 17:15:25 2021-07-03 17:30:20            51
# 279 2021-07-03 17:05:35 2021-07-03 17:35:47            19
#
#     Please fill your full name?        Please fill your email?  \
# 1                 Vishal thakur   vishalthakur850900@gmail.com
# 2              Nikita prajapati          Nikitap8912@gmail.com
# 3                          ansh               ansh00@gmail.com
# ...

# %%
df4.drop_duplicates(['Please fill your full name?', 'Please fill your email?'], keep='first')
# Out:
#              Start time     Completion time  Total points  \
# 1   2021-07-03 14:13:47 2021-07-03 14:18:16             9
# 2   2021-07-03 14:18:11 2021-07-03 14:23:05            14
# 3   2021-07-03 14:19:02 2021-07-03 14:23:40            14
# 4   2021-07-03 14:14:44 2021-07-03 14:26:08             9
# 5   2021-07-03 14:20:41 2021-07-03 14:26:11            15
# ..                  ...                 ...           ...
# 275 2021-07-03 17:12:25 2021-07-03 17:14:54            57
# 276 2021-07-03 16:20:43 2021-07-03 17:17:03            32
# 277 2021-07-03 16:49:17 2021-07-03 17:19:23            45
# 278 2021-07-03 17:15:25 2021-07-03 17:30:20            51
# 279 2021-07-03 17:05:35 2021-07-03 17:35:47            19
#
#     Please fill your full name?        Please fill your email?  \
# 1                 Vishal thakur   vishalthakur850900@gmail.com
# 2              Nikita prajapati          Nikitap8912@gmail.com
# 3                          ansh               ansh00@gmail.com
# ...
