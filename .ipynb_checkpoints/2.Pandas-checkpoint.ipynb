# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    'Name':['rishika', 'aarti', 'javed', 'deepak', 'nitesh', 'piyush', 'mohit', 'yatin', 'khushal'],
    'Gender':pd.Categorical(['F', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M']),
    'Salary':np.random.randint(30, 90, 9),
    'Height':np.random.randint(130, 190, 9),
    'Weight':np.random.randint(50, 90, 9)
})

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      52     164      61
# 1    aarti      F      40     160      61
# 2    javed      M      87     178      58
# 3   deepak      M      32     178      71
# 4   nitesh      M      74     182      89
# 5   piyush      M      55     155      79
# 6    mohit      M      82     140      57
# 7    yatin      M      30     153      64
# 8  khushal      M      85     179      58

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    9 non-null      object
#  1   Gender  9 non-null      category
#  2   Salary  9 non-null      int32
#  3   Height  9 non-null      int32
#  4   Weight  9 non-null      int32
# dtypes: category(1), int32(3), object(1)
# memory usage: 441.0+ bytes

# %%
df.shape
# Out:
# (9, 5)

# %%
df.describe()
# Out:
#           Salary      Height     Weight
# count   9.000000    9.000000   9.000000
# mean   59.666667  165.444444  66.444444
# std    22.929239   14.646767  11.091789
# min    30.000000  140.000000  57.000000
# 25%    40.000000  155.000000  58.000000
# 50%    55.000000  164.000000  61.000000
# 75%    82.000000  178.000000  71.000000
# max    87.000000  182.000000  89.000000

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      52     164      61
# 1    aarti      F      40     160      61
# 2    javed      M      87     178      58
# 3   deepak      M      32     178      71
# 4   nitesh      M      74     182      89
# 5   piyush      M      55     155      79
# 6    mohit      M      82     140      57
# 7    yatin      M      30     153      64
# 8  khushal      M      85     179      58

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
#     anil     52
#     rohan    45
#     khushal  50

# %%
s1 = pd.Series([52, 50, 56, 45], index=['Khushal', 'aman', 'rohan', 'anil'])

# %%
s1
# Out:
# Khushal    52
# aman       50
# rohan      56
# anil       45
# dtype: int64

# %%
dict1 = {
    'A':10,
    'B':20,
    'C':30,
    'D':40
}

# %%
pd.Series(dict1)
# Out:
# A    10
# B    20
# C    30
# D    40
# dtype: int64

# %%
s1
# Out:
# Khushal    52
# aman       50
# rohan      56
# anil       45
# dtype: int64

# %%
s1.to_numpy()
# Out:
# array([52, 50, 56, 45], dtype=int64)

# %%
s1.index
# Out:
# Index(['Khushal', 'aman', 'rohan', 'anil'], dtype='object')

# %%
s1.index.to_list()
# Out:
# ['Khushal', 'aman', 'rohan', 'anil']

# %%
s1.to_json()
# Out:
# '{"Khushal":52,"aman":50,"rohan":56,"anil":45}'

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      52     164      61
# 1    aarti      F      40     160      61
# 2    javed      M      87     178      58
# 3   deepak      M      32     178      71
# 4   nitesh      M      74     182      89
# 5   piyush      M      55     155      79
# 6    mohit      M      82     140      57
# 7    yatin      M      30     153      64
# 8  khushal      M      85     179      58

# %%
df['Name']
# Out:
# 0    rishika
# 1      aarti
# 2      javed
# 3     deepak
# 4     nitesh
# 5     piyush
# 6      mohit
# 7      yatin
# 8    khushal
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
salary = df[['Name', 'Salary']]
salary
# Out:
#       Name  Salary
# 0  rishika      52
# 1    aarti      40
# 2    javed      87
# 3   deepak      32
# 4   nitesh      74
# 5   piyush      55
# 6    mohit      82
# 7    yatin      30
# 8  khushal      85

# %%
# Out:
# 0    rishika
# 1      aarti
# 2      javed
# 3     deepak
# 4     nitesh
# 5     piyush
# 6      mohit
# 7      yatin
# 8    khushal
# Name: Name, dtype: object

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      52     164      61
# 1    aarti      F      40     160      61
# 2    javed      M      87     178      58
# 3   deepak      M      32     178      71
# 4   nitesh      M      74     182      89
# 5   piyush      M      55     155      79
# 6    mohit      M      82     140      57
# 7    yatin      M      30     153      64
# 8  khushal      M      85     179      58

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    9 non-null      object
#  1   Gender  9 non-null      category
#  2   Salary  9 non-null      int32
#  3   Height  9 non-null      int32
#  4   Weight  9 non-null      int32
# dtypes: category(1), int32(3), object(1)
# memory usage: 441.0+ bytes

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      52     164      61
# 1    aarti      F      40     160      61
# 2    javed      M      87     178      58
# 3   deepak      M      32     178      71
# 4   nitesh      M      74     182      89
# 5   piyush      M      55     155      79
# 6    mohit      M      82     140      57
# 7    yatin      M      30     153      64
# 8  khushal      M      85     179      58

# %%
df.drop('Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.drop('Name')
#
# File C:\Anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\Anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
# ...

# %%
df.drop('Name', axis=1)     # immutable operation
# Out:
#   Gender  Salary  Height  Weight
# 0      F      52     164      61
# 1      F      40     160      61
# 2      M      87     178      58
# 3      M      32     178      71
# 4      M      74     182      89
# 5      M      55     155      79
# 6      M      82     140      57
# 7      M      30     153      64
# 8      M      85     179      58

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      52     164      61
# 1    aarti      F      40     160      61
# 2    javed      M      87     178      58
# 3   deepak      M      32     178      71
# 4   nitesh      M      74     182      89
# 5   piyush      M      55     155      79
# 6    mohit      M      82     140      57
# 7    yatin      M      30     153      64
# 8  khushal      M      85     179      58

# %%
df.drop('Name', axis=1, inplace=True)    # mutable operation   name column remove from actual data

# %%
df
# Out:
#   Gender  Salary  Height  Weight
# 0      F      52     164      61
# 1      F      40     160      61
# 2      M      87     178      58
# 3      M      32     178      71
# 4      M      74     182      89
# 5      M      55     155      79
# 6      M      82     140      57
# 7      M      30     153      64
# 8      M      85     179      58

# %%
df.drop('Name', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.drop('Name', axis=1)
#
# File C:\Anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\Anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df
# Out:
#   Gender  Salary  Height  Weight
# 0      F      52     164      61
# 1      F      40     160      61
# 2      M      87     178      58
# 3      M      32     178      71
# 4      M      74     182      89
# 5      M      55     155      79
# 6      M      82     140      57
# 7      M      30     153      64
# 8      M      85     179      58

# %%
df.drop(1)
# Out:
#   Gender  Salary  Height  Weight
# 0      F      52     164      61
# 2      M      87     178      58
# 3      M      32     178      71
# 4      M      74     182      89
# 5      M      55     155      79
# 6      M      82     140      57
# 7      M      30     153      64
# 8      M      85     179      58

# %%
df
# Out:
#   Gender  Salary  Height  Weight
# 0      F      52     164      61
# 1      F      40     160      61
# 2      M      87     178      58
# 3      M      32     178      71
# 4      M      74     182      89
# 5      M      55     155      79
# 6      M      82     140      57
# 7      M      30     153      64
# 8      M      85     179      58

# %%
df.drop([0,1,2,3])
# Out:
#   Gender  Salary  Height  Weight
# 4      M      74     182      89
# 5      M      55     155      79
# 6      M      82     140      57
# 7      M      30     153      64
# 8      M      85     179      58

# %%
df
# Out:
#   Gender  Salary  Height  Weight
# 0      F      52     164      61
# 1      F      40     160      61
# 2      M      87     178      58
# 3      M      32     178      71
# 4      M      74     182      89
# 5      M      55     155      79
# 6      M      82     140      57
# 7      M      30     153      64
# 8      M      85     179      58

# %%
df.loc[[2,3]]
# Out:
#   Gender  Salary  Height  Weight
# 2      M      87     178      58
# 3      M      32     178      71

# %%
df.loc[[2,3], ['Gender', 'Salary']]
# Out:
#   Gender  Salary
# 2      M      87
# 3      M      32

# %%
df
# Out:
#   Gender  Salary  Height  Weight
# 0      F      52     164      61
# 1      F      40     160      61
# 2      M      87     178      58
# 3      M      32     178      71
# 4      M      74     182      89
# 5      M      55     155      79
# 6      M      82     140      57
# 7      M      30     153      64
# 8      M      85     179      58

# %%
df.iloc[[2,3], [0,1]]
# Out:
#   Gender  Salary
# 2      M      87
# 3      M      32

# %%
df.iloc[::2]
# Out:
#   Gender  Salary  Height  Weight
# 0      F      52     164      61
# 2      M      87     178      58
# 4      M      74     182      89
# 6      M      82     140      57
# 8      M      85     179      58

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      55     185      65
# 1    aarti      F      38     144      56
# 2    javed      M      54     172      84
# 3   deepak      M      55     144      82
# 4   nitesh      M      43     167      89
# 5   piyush      M      83     155      64
# 6    mohit      M      87     163      64
# 7    yatin      M      47     184      62
# 8  khushal      M      83     130      69

# %%
df.drop(4)     # immutable operation
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      55     185      65
# 1    aarti      F      38     144      56
# 2    javed      M      54     172      84
# 3   deepak      M      55     144      82
# 5   piyush      M      83     155      64
# 6    mohit      M      87     163      64
# 7    yatin      M      47     184      62
# 8  khushal      M      83     130      69

# %%
df.drop(4, inplace=True)

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      55     185      65
# 1    aarti      F      38     144      56
# 2    javed      M      54     172      84
# 3   deepak      M      55     144      82
# 5   piyush      M      83     155      64
# 6    mohit      M      87     163      64
# 7    yatin      M      47     184      62
# 8  khushal      M      83     130      69

# %%
df.drop('Name', axis=1)
# Out:
#   Gender  Salary  Height  Weight
# 0      F      55     185      65
# 1      F      38     144      56
# 2      M      54     172      84
# 3      M      55     144      82
# 5      M      83     155      64
# 6      M      87     163      64
# 7      M      47     184      62
# 8      M      83     130      69

# %% [markdown]
# ## iloc
#
#                 iloc ---> int based location
#
#                     df.iloc[row_index, col_index]
#
#                     df.iloc[row_slicing, col_slicing]
#
# ## loc
#                 loc  ----> label based location
#
#                     df.loc[row_index, col_index]
#
#                     df.loc[row_slicing, col_slicing]

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      55     185      65
# 1    aarti      F      38     144      56
# 2    javed      M      54     172      84
# 3   deepak      M      55     144      82
# 5   piyush      M      83     155      64
# 6    mohit      M      87     163      64
# 7    yatin      M      47     184      62
# 8  khushal      M      83     130      69

# %%
df.iloc[4]
# Out:
# Name      piyush
# Gender         M
# Salary        83
# Height       155
# Weight        64
# Name: 5, dtype: object

# %%
df.iloc[4, 2]
# Out:
# 83

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      55     185      65
# 1    aarti      F      38     144      56
# 2    javed      M      54     172      84
# 3   deepak      M      55     144      82
# 5   piyush      M      83     155      64
# 6    mohit      M      87     163      64
# 7    yatin      M      47     184      62
# 8  khushal      M      83     130      69

# %%
df.iloc[3:6]
# Out:
#      Name Gender  Salary  Height  Weight
# 3  deepak      M      55     144      82
# 5  piyush      M      83     155      64
# 6   mohit      M      87     163      64

# %%
df.iloc[3:6, 2:4]
# Out:
#    Salary  Height
# 3      55     144
# 5      83     155
# 6      87     163

# %%
df.iloc[3:6, [0, 2,3]]
# Out:
#      Name  Salary  Height
# 3  deepak      55     144
# 5  piyush      83     155
# 6   mohit      87     163

# %%
df.index
# Out:
# Int64Index([0, 1, 2, 3, 5, 6, 7, 8], dtype='int64')

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'Salary', 'Height', 'Weight'], dtype='object')

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      55     185      65
# 1    aarti      F      38     144      56
# 2    javed      M      54     172      84
# 3   deepak      M      55     144      82
# 5   piyush      M      83     155      64
# 6    mohit      M      87     163      64
# 7    yatin      M      47     184      62
# 8  khushal      M      83     130      69

# %%
df.loc[::2, ::2]
# Out:
#       Name  Salary  Weight
# 0  rishika      55      65
# 2    javed      54      84
# 5   piyush      83      64
# 7    yatin      47      62

# %%
df.loc[[0,2,5], 'Name':'Salary']
# Out:
#       Name Gender  Salary
# 0  rishika      F      55
# 2    javed      M      54
# 5   piyush      M      83

# %%
df
# Out:
#       Name Gender  Salary  Height  Weight
# 0  rishika      F      55     185      65
# 1    aarti      F      38     144      56
# 2    javed      M      54     172      84
# 3   deepak      M      55     144      82
# 5   piyush      M      83     155      64
# 6    mohit      M      87     163      64
# 7    yatin      M      47     184      62
# 8  khushal      M      83     130      69

# %%
df.loc[[0, 5, 8], 'Name':'Height':3]
# Out:
#       Name  Height
# 0  rishika     185
# 5   piyush     155
# 8  khushal     130

# %% [markdown]
# ## time series

# %%
pd.date_range('2024/02/12', periods=10)
# Out:
# DatetimeIndex(['2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15',
#                '2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19',
#                '2024-02-20', '2024-02-21'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2024/02/12', periods=10, freq='2D')
# Out:
# DatetimeIndex(['2024-02-12', '2024-02-14', '2024-02-16', '2024-02-18',
#                '2024-02-20', '2024-02-22', '2024-02-24', '2024-02-26',
#                '2024-02-28', '2024-03-01'],
#               dtype='datetime64[ns]', freq='2D')

# %%
pd.date_range('2024/02/12', '2024/04/17', freq='5D')
# Out:
# DatetimeIndex(['2024-02-12', '2024-02-17', '2024-02-22', '2024-02-27',
#                '2024-03-03', '2024-03-08', '2024-03-13', '2024-03-18',
#                '2024-03-23', '2024-03-28', '2024-04-02', '2024-04-07',
#                '2024-04-12', '2024-04-17'],
#               dtype='datetime64[ns]', freq='5D')

# %%
pd.date_range('2024/01/01', periods=12, freq='M')
# Out:
# DatetimeIndex(['2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('2024/04/17 04:22 pm', periods=5)
# Out:
# DatetimeIndex(['2024-04-17 16:22:00', '2024-04-18 16:22:00',
#                '2024-04-19 16:22:00', '2024-04-20 16:22:00',
#                '2024-04-21 16:22:00'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2024/04/17 04:22 pm', periods=5, freq='T')
# Out:
# DatetimeIndex(['2024-04-17 16:22:00', '2024-04-17 16:23:00',
#                '2024-04-17 16:24:00', '2024-04-17 16:25:00',
#                '2024-04-17 16:26:00'],
#               dtype='datetime64[ns]', freq='T')

# %%
pd.date_range('2024/04/17 04:22 pm', periods=5, freq='10T')
# Out:
# DatetimeIndex(['2024-04-17 16:22:00', '2024-04-17 16:32:00',
#                '2024-04-17 16:42:00', '2024-04-17 16:52:00',
#                '2024-04-17 17:02:00'],
#               dtype='datetime64[ns]', freq='10T')

# %%
temp = [16.5, 18.4, 20.3, 22.5, 25.8, 28.7, 30.5, 32.4, 28, 26, 22]

# %%
len(temp)
# Out:
# 11

# %%
date_range = pd.date_range('2024/04/17 8:00am', periods=11, freq='H')
date_range
# Out:
# DatetimeIndex(['2024-04-17 08:00:00', '2024-04-17 09:00:00',
#                '2024-04-17 10:00:00', '2024-04-17 11:00:00',
#                '2024-04-17 12:00:00', '2024-04-17 13:00:00',
#                '2024-04-17 14:00:00', '2024-04-17 15:00:00',
#                '2024-04-17 16:00:00', '2024-04-17 17:00:00',
#                '2024-04-17 18:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
s1 = pd.Series(temp, index=date_range)

# %%
s1
# Out:
# 2024-04-17 08:00:00    16.5
# 2024-04-17 09:00:00    18.4
# 2024-04-17 10:00:00    20.3
# 2024-04-17 11:00:00    22.5
# 2024-04-17 12:00:00    25.8
# 2024-04-17 13:00:00    28.7
# 2024-04-17 14:00:00    30.5
# 2024-04-17 15:00:00    32.4
# 2024-04-17 16:00:00    28.0
# 2024-04-17 17:00:00    26.0
# 2024-04-17 18:00:00    22.0
# Freq: H, dtype: float64

# %%
s1.plot(kind='bar')
# Out:
# <Axes: >

# %%
df = pd.read_csv('covid_19_india.csv')
df
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Date                      18110 non-null  object
#  2   Time                      18110 non-null  object
#  3   State/UnionTerritory      18110 non-null  object
#  4   ConfirmedIndianNational   18110 non-null  object
#  5   ConfirmedForeignNational  18110 non-null  object
#  6   Cured                     18110 non-null  int64
#  7   Deaths                    18110 non-null  int64
#  8   Confirmed                 18110 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                 Sno         Cured         Deaths     Confirmed
# count  18110.000000  1.811000e+04   18110.000000  1.811000e+04
# mean    9055.500000  2.786375e+05    4052.402264  3.010314e+05
# std     5228.051023  6.148909e+05   10919.076411  6.561489e+05
# min        1.000000  0.000000e+00       0.000000  0.000000e+00
# 25%     4528.250000  3.360250e+03      32.000000  4.376750e+03
# 50%     9055.500000  3.336400e+04     588.000000  3.977350e+04
# 75%    13582.750000  2.788698e+05    3643.750000  3.001498e+05
# max    18110.000000  6.159676e+06  134201.000000  6.363442e+06

# %%
df.isna()
# Out:
#          Sno   Date   Time  State/UnionTerritory  ConfirmedIndianNational  \
# 0      False  False  False                 False                    False
# 1      False  False  False                 False                    False
# 2      False  False  False                 False                    False
# 3      False  False  False                 False                    False
# 4      False  False  False                 False                    False
# ...      ...    ...    ...                   ...                      ...
# 18105  False  False  False                 False                    False
# 18106  False  False  False                 False                    False
# 18107  False  False  False                 False                    False
# 18108  False  False  False                 False                    False
# 18109  False  False  False                 False                    False
#
#        ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %%
df.isna().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %%
df
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
s1 = df['State/UnionTerritory']
s1
# Out:
# 0               Kerala
# 1               Kerala
# 2               Kerala
# 3               Kerala
# 4               Kerala
#              ...
# 18105        Telangana
# 18106          Tripura
# 18107      Uttarakhand
# 18108    Uttar Pradesh
# 18109      West Bengal
# Name: State/UnionTerritory, Length: 18110, dtype: object

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=18110, step=1)

# %%
s1.values
# Out:
# array(['Kerala', 'Kerala', 'Kerala', ..., 'Uttarakhand', 'Uttar Pradesh',
#        'West Bengal'], dtype=object)

# %%
data = s1.value_counts()
data
# Out:
# Kerala                                      560
# Delhi                                       528
# Rajasthan                                   527
# Uttar Pradesh                               526
# Haryana                                     526
# Ladakh                                      523
# Tamil Nadu                                  523
# Punjab                                      521
# Jammu and Kashmir                           521
# Maharashtra                                 520
# Karnataka                                   520
# Andhra Pradesh                              518
# Uttarakhand                                 515
# Odisha                                      514
# Puducherry                                  512
# West Bengal                                 512
# Chhattisgarh                                511
# Chandigarh                                  511
# Gujarat                                     510
# Himachal Pradesh                            508
# ...

# %%
data.index
# Out:
# Index(['Kerala', 'Delhi', 'Rajasthan', 'Uttar Pradesh', 'Haryana', 'Ladakh',
#        'Tamil Nadu', 'Punjab', 'Jammu and Kashmir', 'Maharashtra', 'Karnataka',
#        'Andhra Pradesh', 'Uttarakhand', 'Odisha', 'Puducherry', 'West Bengal',
#        'Chhattisgarh', 'Chandigarh', 'Gujarat', 'Himachal Pradesh',
#        'Madhya Pradesh', 'Bihar', 'Manipur', 'Mizoram',
#        'Andaman and Nicobar Islands', 'Goa', 'Assam', 'Jharkhand',
#        'Arunachal Pradesh', 'Tripura', 'Meghalaya',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Nagaland', 'Sikkim',
#        'Telengana', 'Lakshadweep', 'Telangana',
#        'Cases being reassigned to states', 'Unassigned',
#        'Dadra and Nagar Haveli', 'Bihar****', 'Daman & Diu',
#        'Madhya Pradesh***', 'Himanchal Pradesh', 'Karanataka',
#        'Maharashtra***'],
#       dtype='object')

# %%
data.values
# Out:
# array([560, 528, 527, 526, 526, 523, 523, 521, 521, 520, 520, 518, 515,
#        514, 512, 512, 511, 511, 510, 508, 508, 506, 506, 505, 504, 504,
#        498, 498, 496, 492, 485, 461, 452, 445, 426, 244, 102,  60,   3,
#          2,   2,   1,   1,   1,   1,   1], dtype=int64)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16, 9), dpi=300)
plt.bar(data.index, data.values)
plt.xticks(rotation=90)
plt.show()

# %%
netflix = pd.read_csv('netflix-rotten-tomatoes-metacritic-imdb.csv')
netflix
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %%
netflix.columns
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15480 entries, 0 to 15479
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  15480 non-null  object
#  1   Genre                  13770 non-null  object
#  2   Tags                   15413 non-null  object
#  3   Languages              13545 non-null  object
#  4   Series or Movie        15480 non-null  object
#  5   Hidden Gem Score       13379 non-null  float64
#  6   Country Availability   15461 non-null  object
#  7   Runtime                15479 non-null  object
#  8   Director               10772 non-null  object
#  9   Writer                 11150 non-null  object
#  10  Actors                 13555 non-null  object
#  11  View Rating            8456 non-null   object
#  12  IMDb Score             13381 non-null  float64
#  13  Rotten Tomatoes Score  6382 non-null   float64
# ...

# %%
netflix.isna().sum()
# Out:
# Title                        0
# Genre                     1710
# Tags                        67
# Languages                 1935
# Series or Movie              0
# Hidden Gem Score          2101
# Country Availability        19
# Runtime                      1
# Director                  4708
# Writer                    4330
# Actors                    1925
# View Rating               7024
# IMDb Score                2099
# Rotten Tomatoes Score     9098
# Metacritic Score         11144
# Awards Received           9405
# Awards Nominated For      7819
# Boxoffice                11473
# Release Date              2107
# Netflix Release Date         0
# Production House         10331
# Netflix Link                 0
# IMDb Link                 2303
# Summary                      9
# IMDb Votes                2101
# Image                        0
# Poster                    3638
# TMDb Trailer              8286
# Trailer Site              8286
# dtype: int64

# %%
netflix.isna().sum().sort_values()
# Out:
# Title                        0
# Netflix Release Date         0
# Image                        0
# Series or Movie              0
# Netflix Link                 0
# Runtime                      1
# Summary                      9
# Country Availability        19
# Tags                        67
# Genre                     1710
# Actors                    1925
# Languages                 1935
# IMDb Score                2099
# IMDb Votes                2101
# Hidden Gem Score          2101
# Release Date              2107
# IMDb Link                 2303
# Poster                    3638
# Writer                    4330
# Director                  4708
# View Rating               7024
# Awards Nominated For      7819
# Trailer Site              8286
# TMDb Trailer              8286
# Rotten Tomatoes Score     9098
# Awards Received           9405
# Production House         10331
# Metacritic Score         11144
# Boxoffice                11473
# dtype: int64

# %%
netflix.shape
# Out:
# (15480, 29)

# %%
netflix.isna().sum().sort_values(ascending=False)
# Out:
# Boxoffice                11473
# Metacritic Score         11144
# Production House         10331
# Awards Received           9405
# Rotten Tomatoes Score     9098
# TMDb Trailer              8286
# Trailer Site              8286
# Awards Nominated For      7819
# View Rating               7024
# Director                  4708
# Writer                    4330
# Poster                    3638
# IMDb Link                 2303
# Release Date              2107
# Hidden Gem Score          2101
# IMDb Votes                2101
# IMDb Score                2099
# Languages                 1935
# Actors                    1925
# Genre                     1710
# Tags                        67
# Country Availability        19
# Summary                      9
# Runtime                      1
# Netflix Link                 0
# Image                        0
# Netflix Release Date         0
# Series or Movie              0
# Title                        0
# dtype: int64

# %%
netflix.isna().sum().sort_values(ascending=False) / netflix.shape[0] * 100
# Out:
# Boxoffice                74.114987
# Metacritic Score         71.989664
# Production House         66.737726
# Awards Received          60.755814
# Rotten Tomatoes Score    58.772610
# TMDb Trailer             53.527132
# Trailer Site             53.527132
# Awards Nominated For     50.510336
# View Rating              45.374677
# Director                 30.413437
# Writer                   27.971576
# Poster                   23.501292
# IMDb Link                14.877261
# Release Date             13.611111
# Hidden Gem Score         13.572351
# IMDb Votes               13.572351
# IMDb Score               13.559432
# Languages                12.500000
# Actors                   12.435401
# Genre                    11.046512
# Tags                      0.432817
# Country Availability      0.122739
# Summary                   0.058140
# Runtime                   0.006460
# Netflix Link              0.000000
# Image                     0.000000
# Netflix Release Date      0.000000
# ...
