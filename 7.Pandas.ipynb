# %% [markdown]
#        loc, iloc, at, iat
#        map
#        groupby
#        apply
#        query
#        where
#        agg
#
#        eval
#        drop_duplicate
#        pivot table    ---> wide to short short to wide

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print([i for i in dir(pd.DataFrame) if not i.startswith('__')])
# Out:
# ['T', '_AXIS_LEN', '_AXIS_NAMES', '_AXIS_NUMBERS', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '_accessors', '_accum_func', '_add_numeric_operations', '_agg_by_level', '_agg_examples_doc', '_agg_summary_and_see_also_doc', '_align_frame', '_align_series', '_append', '_arith_method', '_as_manager', '_box_col_values', '_can_fast_transpose', '_check_inplace_and_allows_duplicate_labels', '_check_inplace_setting', '_check_is_chained_assignment_possible', '_check_label_or_level_ambiguity', '_check_setitem_copy', '_clear_item_cache', '_clip_with_one_bound', '_clip_with_scalar', '_cmp_method', '_combine_frame', '_consolidate', '_consolidate_inplace', '_construct_axes_dict', '_construct_axes_from_arguments', '_construct_result', '_constructor', '_constructor_sliced', '_convert', '_count_level', '_data', '_dir_additions', '_dir_deletions', '_dispatch_frame_op', '_drop_axis', '_drop_labels_or_levels', '_ensure_valid_index', '_find_valid_index', '_from_arrays', '_get_agg_axis', '_ge
# ...

# %%
arr = np.random.randint(20, 40, (10,4))
arr
# Out:
# array([[31, 24, 20, 37],
#        [37, 37, 22, 30],
#        [26, 21, 36, 30],
#        [31, 38, 32, 20],
#        [30, 33, 35, 23],
#        [39, 24, 28, 28],
#        [29, 29, 26, 34],
#        [31, 33, 29, 26],
#        [29, 24, 20, 36],
#        [21, 37, 27, 36]])

# %%
df = pd.DataFrame(arr, index=range(10),columns=['India', 'Usa', 'China', 'Aus'])
df
# Out:
#    India  Usa  China  Aus
# 0     31   24     20   37
# 1     37   37     22   30
# 2     26   21     36   30
# 3     31   38     32   20
# 4     30   33     35   23
# 5     39   24     28   28
# 6     29   29     26   34
# 7     31   33     29   26
# 8     29   24     20   36
# 9     21   37     27   36

# %%
df.sort_values('India')
# Out:
#    India  Usa  China  Aus
# 9     21   37     27   36
# 2     26   21     36   30
# 6     29   29     26   34
# 8     29   24     20   36
# 4     30   33     35   23
# 0     31   24     20   37
# 3     31   38     32   20
# 7     31   33     29   26
# 1     37   37     22   30
# 5     39   24     28   28

# %%
df.sort_values('India', ascending=False)
# Out:
#    India  Usa  China  Aus
# 5     39   24     28   28
# 1     37   37     22   30
# 0     31   24     20   37
# 3     31   38     32   20
# 7     31   33     29   26
# 4     30   33     35   23
# 6     29   29     26   34
# 8     29   24     20   36
# 2     26   21     36   30
# 9     21   37     27   36

# %%
df.sort_values('India')
# Out:
#    India  Usa  China  Aus
# 9     21   37     27   36
# 2     26   21     36   30
# 6     29   29     26   34
# 8     29   24     20   36
# 4     30   33     35   23
# 0     31   24     20   37
# 3     31   38     32   20
# 7     31   33     29   26
# 1     37   37     22   30
# 5     39   24     28   28

# %%
df.sort_values(['India', 'China'])
# Out:
#    India  Usa  China  Aus
# 9     21   37     27   36
# 2     26   21     36   30
# 8     29   24     20   36
# 6     29   29     26   34
# 4     30   33     35   23
# 0     31   24     20   37
# 7     31   33     29   26
# 3     31   38     32   20
# 1     37   37     22   30
# 5     39   24     28   28

# %%
df
# Out:
#    India  Usa  China  Aus
# 0     31   24     20   37
# 1     37   37     22   30
# 2     26   21     36   30
# 3     31   38     32   20
# 4     30   33     35   23
# 5     39   24     28   28
# 6     29   29     26   34
# 7     31   33     29   26
# 8     29   24     20   36
# 9     21   37     27   36

# %%
df
# Out:
#    India  Usa  China  Aus
# 0     31   24     20   37
# 1     37   37     22   30
# 2     26   21     36   30
# 3     31   38     32   20
# 4     30   33     35   23
# 5     39   24     28   28
# 6     29   29     26   34
# 7     31   33     29   26
# 8     29   24     20   36
# 9     21   37     27   36

# %%
df.sort_values(0, axis=1)
# Out:
#    China  Usa  India  Aus
# 0     20   24     31   37
# 1     22   37     37   30
# 2     36   21     26   30
# 3     32   38     31   20
# 4     35   33     30   23
# 5     28   24     39   28
# 6     26   29     29   34
# 7     29   33     31   26
# 8     20   24     29   36
# 9     27   37     21   36

# %%
df = pd.DataFrame({
    'Gender':pd.Categorical(np.random.choice(['Male', 'Female'], 100, True)),
    'Country':np.random.choice(['India', 'Usa', 'Aus', 'Uk'], 100, True),
    'Salary':np.random.randint(30, 90, 100),
    'Weight':np.random.randint(50, 110, 100),
    'Height':np.random.randint(120, 190, 100)
})

# %%
df
# Out:
#     Gender Country  Salary  Weight  Height
# 0     Male   India      31      64     182
# 1   Female      Uk      83      52     179
# 2     Male   India      53      58     136
# 3     Male   India      67      61     178
# 4     Male   India      69     100     164
# ..     ...     ...     ...     ...     ...
# 95  Female     Usa      84      91     184
# 96  Female   India      32      91     151
# 97  Female      Uk      46      99     165
# 98    Male   India      79     101     141
# 99    Male   India      84      91     159
#
# [100 rows x 5 columns]

# %%
df.query("Country == 'Uk'")
# Out:
#     Gender Country  Salary  Weight  Height
# 1   Female      Uk      83      52     179
# 8     Male      Uk      68      57     189
# 13    Male      Uk      50     101     155
# 24  Female      Uk      81      77     174
# 26  Female      Uk      33      79     186
# 35  Female      Uk      72     105     147
# 37    Male      Uk      34     103     172
# 44  Female      Uk      35      83     145
# 48  Female      Uk      65      60     182
# 52  Female      Uk      45     101     182
# 53    Male      Uk      50      69     145
# 61    Male      Uk      54      69     168
# 62    Male      Uk      86     100     175
# 64    Male      Uk      86      66     169
# 65  Female      Uk      65     106     168
# 66  Female      Uk      80      54     166
# 75    Male      Uk      38      50     177
# 97  Female      Uk      46      99     165

# %%
df[df.eval("Country == 'Uk'")]
# Out:
#     Gender Country  Salary  Weight  Height
# 1   Female      Uk      83      52     179
# 8     Male      Uk      68      57     189
# 13    Male      Uk      50     101     155
# 24  Female      Uk      81      77     174
# 26  Female      Uk      33      79     186
# 35  Female      Uk      72     105     147
# 37    Male      Uk      34     103     172
# 44  Female      Uk      35      83     145
# 48  Female      Uk      65      60     182
# 52  Female      Uk      45     101     182
# 53    Male      Uk      50      69     145
# 61    Male      Uk      54      69     168
# 62    Male      Uk      86     100     175
# 64    Male      Uk      86      66     169
# 65  Female      Uk      65     106     168
# 66  Female      Uk      80      54     166
# 75    Male      Uk      38      50     177
# 97  Female      Uk      46      99     165

# %% [markdown]
#     df['wh'] = df['Weight'] + df['Height']

# %%
df.assign(
    wh = df['Weight'] + df['Height']
    )
# Out:
#     Gender Country  Salary  Weight  Height   wh
# 0     Male   India      31      64     182  246
# 1   Female      Uk      83      52     179  231
# 2     Male   India      53      58     136  194
# 3     Male   India      67      61     178  239
# 4     Male   India      69     100     164  264
# ..     ...     ...     ...     ...     ...  ...
# 95  Female     Usa      84      91     184  275
# 96  Female   India      32      91     151  242
# 97  Female      Uk      46      99     165  264
# 98    Male   India      79     101     141  242
# 99    Male   India      84      91     159  250
#
# [100 rows x 6 columns]

# %%
df1 = df.assign(
    wh = df['Weight'] + df['Height'],
    rupees = df['Salary'] * 1000
    )

# %%
df1
# Out:
#     Gender Country  Salary  Weight  Height   wh  rupees
# 0     Male   India      31      64     182  246   31000
# 1   Female      Uk      83      52     179  231   83000
# 2     Male   India      53      58     136  194   53000
# 3     Male   India      67      61     178  239   67000
# 4     Male   India      69     100     164  264   69000
# ..     ...     ...     ...     ...     ...  ...     ...
# 95  Female     Usa      84      91     184  275   84000
# 96  Female   India      32      91     151  242   32000
# 97  Female      Uk      46      99     165  264   46000
# 98    Male   India      79     101     141  242   79000
# 99    Male   India      84      91     159  250   84000
#
# [100 rows x 7 columns]

# %%
df
# Out:
#     Gender Country  Salary  Weight  Height
# 0     Male   India      31      64     182
# 1   Female      Uk      83      52     179
# 2     Male   India      53      58     136
# 3     Male   India      67      61     178
# 4     Male   India      69     100     164
# ..     ...     ...     ...     ...     ...
# 95  Female     Usa      84      91     184
# 96  Female   India      32      91     151
# 97  Female      Uk      46      99     165
# 98    Male   India      79     101     141
# 99    Male   India      84      91     159
#
# [100 rows x 5 columns]

# %%
df.eval("Height + Weight")
# Out:
# 0     246
# 1     231
# 2     194
# 3     239
# 4     264
#      ...
# 95    275
# 96    242
# 97    264
# 98    242
# 99    250
# Length: 100, dtype: int32

# %%
df.eval("hw = Height + Weight")
# Out:
#     Gender Country  Salary  Weight  Height   hw
# 0     Male   India      31      64     182  246
# 1   Female      Uk      83      52     179  231
# 2     Male   India      53      58     136  194
# 3     Male   India      67      61     178  239
# 4     Male   India      69     100     164  264
# ..     ...     ...     ...     ...     ...  ...
# 95  Female     Usa      84      91     184  275
# 96  Female   India      32      91     151  242
# 97  Female      Uk      46      99     165  264
# 98    Male   India      79     101     141  242
# 99    Male   India      84      91     159  250
#
# [100 rows x 6 columns]

# %%
df
# Out:
#     Gender Country  Salary  Weight  Height
# 0     Male   India      31      64     182
# 1   Female      Uk      83      52     179
# 2     Male   India      53      58     136
# 3     Male   India      67      61     178
# 4     Male   India      69     100     164
# ..     ...     ...     ...     ...     ...
# 95  Female     Usa      84      91     184
# 96  Female   India      32      91     151
# 97  Female      Uk      46      99     165
# 98    Male   India      79     101     141
# 99    Male   India      84      91     159
#
# [100 rows x 5 columns]

# %%
df[df.eval("Weight > 90 | Height >180")]
# Out:
#     Gender Country  Salary  Weight  Height
# 0     Male   India      31      64     182
# 4     Male   India      69     100     164
# 5     Male     Aus      40     105     179
# 8     Male      Uk      68      57     189
# 9   Female   India      70     103     173
# 10    Male     Usa      70     107     170
# 13    Male      Uk      50     101     155
# 15  Female     Aus      86      88     184
# 18    Male   India      71      96     138
# 21  Female   India      49     105     184
# 23    Male   India      85      76     185
# 25  Female     Usa      48     108     147
# 26  Female      Uk      33      79     186
# 33  Female     Usa      77      53     183
# 35  Female      Uk      72     105     147
# 37    Male      Uk      34     103     172
# 38    Male   India      35      97     176
# 39  Female     Aus      41     101     181
# 40  Female     Aus      40      95     166
# 41  Female   India      30      68     182
# 43    Male     Usa      83     107     147
# ...

# %%
df
# Out:
#     Gender Country  Salary  Weight  Height
# 0     Male   India      31      64     182
# 1   Female      Uk      83      52     179
# 2     Male   India      53      58     136
# 3     Male   India      67      61     178
# 4     Male   India      69     100     164
# ..     ...     ...     ...     ...     ...
# 95  Female     Usa      84      91     184
# 96  Female   India      32      91     151
# 97  Female      Uk      46      99     165
# 98    Male   India      79     101     141
# 99    Male   India      84      91     159
#
# [100 rows x 5 columns]

# %%
df.eval("owoh = Weight > 90 & Height >180")
# Out:
#     Gender Country  Salary  Weight  Height   owoh
# 0     Male   India      31      64     182  False
# 1   Female      Uk      83      52     179  False
# 2     Male   India      53      58     136  False
# 3     Male   India      67      61     178  False
# 4     Male   India      69     100     164  False
# ..     ...     ...     ...     ...     ...    ...
# 95  Female     Usa      84      91     184   True
# 96  Female   India      32      91     151  False
# 97  Female      Uk      46      99     165  False
# 98    Male   India      79     101     141  False
# 99    Male   India      84      91     159  False
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#    Gender Country  Salary  Weight  Height
# 0    Male   India      31      64     182
# 1  Female      Uk      83      52     179
# 2    Male   India      53      58     136
# 3    Male   India      67      61     178
# 4    Male   India      69     100     164

# %%
w = 80
h = 175

df.eval("owoh = Weight > @w & Height >@h")
# Out:
#     Gender Country  Salary  Weight  Height   owoh
# 0     Male   India      31      64     182  False
# 1   Female      Uk      83      52     179  False
# 2     Male   India      53      58     136  False
# 3     Male   India      67      61     178  False
# 4     Male   India      69     100     164  False
# ..     ...     ...     ...     ...     ...    ...
# 95  Female     Usa      84      91     184   True
# 96  Female   India      32      91     151  False
# 97  Female      Uk      46      99     165  False
# 98    Male   India      79     101     141  False
# 99    Male   India      84      91     159  False
#
# [100 rows x 6 columns]

# %%
df.eval("owoh = Weight > 90 & Height >180", inplace=True)

# %%
df
# Out:
#     Gender Country  Salary  Weight  Height   owoh
# 0     Male   India      31      64     182  False
# 1   Female      Uk      83      52     179  False
# 2     Male   India      53      58     136  False
# 3     Male   India      67      61     178  False
# 4     Male   India      69     100     164  False
# ..     ...     ...     ...     ...     ...    ...
# 95  Female     Usa      84      91     184   True
# 96  Female   India      32      91     151  False
# 97  Female      Uk      46      99     165  False
# 98    Male   India      79     101     141  False
# 99    Male   India      84      91     159  False
#
# [100 rows x 6 columns]

# %%
domains = pd.read_excel('c://Users/user/Desktop/domains.xlsx')
domains
# Out:
#                 Domain
# 0      11h11-design.fr
# 1             1team.ai
# 2          2-doors.com
# 3          23andme.com
# 4    247commerce.co.uk
# ..                 ...
# 512  yantradigital.com
# 513   yarbosoftlab.com
# 514          yefx.info
# 515         zaelot.com
# 516       zestmoney.in
#
# [517 rows x 1 columns]

# %%
domains.loc[0, 'Domain']
# Out:
# '11h11-design.fr'

# %%
import requests

# %%
requests.get('https://11h11-design.fr')
# Out:
# <Response [503]>

# %%
ls = []
for i in domains['Domain']:
    resp = requests.get('https://'+i)
    try:
        ls.append(resp.status_code)
    except:
        ls.append(None)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %%
ls
# Out:
# [503, 200]

# %%
requests.get("https://2-doors.com")
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...
